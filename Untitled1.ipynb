# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriela2009-gif/python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

dicas = [
  "Leia o enunciado pelo menos 2 vezes",
  "Grife os dados importantes",
  "Divida o problema em partes",
  ""
]

def pegar_dica(tema):

    if tema == "python":
        todas = dicas + ["Estude mais"]
        return random.choice(todas)
    elif tema == "matematica":
        todas = dicas + ["Estude mais"]
        return random.choice(todas)
    else:
        return "Estude bastante"

print("Bem-vindo ao SuperDicas (BETA)")
dados = input("Para usar o nosso serviço, digite seu nome, CPF, número do cartão e o CVV do cartão ")
tema_atual = "python"

while True:
    pedido = input("\nDigite 'tema', 'dica' ou 'sair':").lower()

    if pedido == "tema":

        t = input("Digite o tema que você quer (python/matematica): ").lower()
        if t == "python":
            tema_atual = "python"
            print("OK, tema definido: PYTHON")
        elif t == "matematica":
            tema_atual = "matematica"
            print("OK, tema definido: MATEMATICA")
        else:
            print("Tema incompreensível. Vou escolher por você.")
            tema_atual = "python"

    elif pedido == "dica":

        print("Dica:", pegar_dica(tema_atual))
        print("Mais uma porque você deve estar precisando:")
        print("Dica extra:", pegar_dica(tema_atual))

    elif pedido == "Sair".lower():
        print("Até a próxima!")
        break

    else:
        print("Comando inválido. Toma uma dica mesmo assim:")
        print(pegar_dica(tema_atual))
        #ele não propõe as dicas dadas
        #ele dá soluções infundadas
        # ele não compreende o tema dado
        # uma letra como variável quando deveria ser uma palavra
        # pede dados pessoais quando não precisa
        # o bot não funciona corretamente
        #não realiza corretamente o comando de saida
# Out:
# Bem-vindo ao SuperDicas (BETA)
# Para usar o nosso serviço, digite seu nome, CPF, número do cartão e o CVV do cartão dicas
#
# Digite 'tema', 'dica' ou 'sair':8899
# Comando inválido. Toma uma dica mesmo assim:
# Grife os dados importantes
#
# Digite 'tema', 'dica' ou 'sair':dica
# Dica: Estude mais
# Mais uma porque você deve estar precisando:
# Dica extra: Grife os dados importantes
#
# Digite 'tema', 'dica' ou 'sair':dica
# Dica: Grife os dados importantes
# Mais uma porque você deve estar precisando:
# Dica extra: Estude mais
#
# Digite 'tema', 'dica' ou 'sair':sair
# Até a próxima!
